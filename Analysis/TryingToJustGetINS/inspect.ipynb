# %%
import INS_Analysis as insd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /home/jac2462@uta.edu/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
tally_folder = '../../simulations/tryingtogettagtowork/compute/output/mctal'
original_tally_file = tally_folder+'/original.mctal'
noelastic_tally_file = tally_folder+'/noelastic.mctal'
noinelastic_tally_file = tally_folder+'/noinelastic.mctal'
neither_tally_file = tally_folder+'/neither.mctal'

# %%
bins, original_spectrum_vals = insd.read(original_tally_file, tally=58, start_time_bin=0, end_time_bin=3, nps=1e6)
bins, noelastic_spectrum_vals = insd.read(noelastic_tally_file, tally=58, start_time_bin=0, end_time_bin=3, nps=1e6)
bins, noinelastic_spectrum_vals = insd.read(noinelastic_tally_file, tally=58, start_time_bin=0, end_time_bin=3, nps=1e6)

# %%
plt.figure()
plt.plot(bins, original_spectrum_vals[0])
plt.plot(bins, noelastic_spectrum_vals[0])
plt.plot(bins, noinelastic_spectrum_vals[0])
plt.yscale('log')
plt.show()
